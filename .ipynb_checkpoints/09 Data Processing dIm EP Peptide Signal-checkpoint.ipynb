# %%
import numpy as np
import pandas as pd
import os

from scipy import stats

import sys
sys.path.append('/home/galina/PythonProjects/common_functions')
import peptides as pep

# %% [markdown]
# # Peptide data cleaning

# %%
data = pd.read_csv('EP signals from dIm EP and dR RT.csv', header = 0)

drop_pep = ['X']

drop_col = ['Column',
            'Row',
            'Peptide SD',
            'Peptide Median',
            'Peptide Max',
            'Peptide Min',
            'Streptavidin SD',
            'Streptavidin Median',
            'Streptavidin Max',
            'Streptavidin Min',
            'Baseline Mean',
            'Dissociation SNR']
data.rename(columns = {'Index' : 'Grid Index',
                       'Label' : 'Peptide'}, inplace = True)

# Add 'Bad' columns
bad_indices = [int(x) for x in np.genfromtxt("bad spots.txt", delimiter="\n")]
binary_bad = [False] * len(data)
for i in bad_indices:
    binary_bad[i] = True

data['Bad EP']         = binary_bad
data['Bad RT']         = (data['Association SNR'].isnull())
data['Peptide Length'] = data['Peptide'].map(pep.weight)
data['Peptide Weight'] = data['Peptide'].map(lambda x : len(str(x)))

data.drop(drop_col, axis = 1, inplace = True)
data.head()
# Out:
#    Grid Index        Peptide  Peptide Readout  Peptide Mean  Peptide MAD  \
# 0           0       WTHPQFAT         0.000387      0.000899     0.000241
# 1           1       WTHPQFAT         0.000360      0.000606     0.000338
# 2           2       WTHLQFAT         0.000223      0.000304     0.000148
# 3           3  NGQFQVWIPLAQK         0.002042      0.001883     0.000265
# 4           4      LQLHPQAGK         0.003436      0.003312     0.000187
#
#    Streptavidin Readout  Streptavidin Mean  Streptavidin MAD  Baseline Noise  \
# 0              0.001759           0.001738          0.000143        0.000211
# 1              0.001839           0.001741          0.000107        0.000263
# 2             -0.000018           0.000005          0.000095        0.000237
# 3             -0.000196          -0.000061          0.000107        0.000237
# 4              0.000476           0.000580          0.000101        0.000237
#
#    Association Mean  Dissociation Mean  Association SNR Bad EP Bad RT  \
# 0          0.001505           0.001104         7.134546  False  False
# 1          0.000903           0.000765         3.429684  False  False
# 2         -0.000066           0.000072        -0.280433  False  False
# 3         -0.000120          -0.000145        -0.504192  False  False
# 4          0.000639           0.000319         2.693665  False  False
#
#    Peptide Length  Peptide Weight
# 0         987.083               8
# 1         987.083               8
# 2        1003.126               8
# 3        1528.777              13
# 4         991.160               9

# %%
# remove NaNs, Xs and bad spots
data = data.dropna()
data = data[ data['Peptide'] != 'X' ]
data = data[ data['Bad'] == 0 ]

data.sort('Peptide', inplace = True)
data = data.reset_index(drop = True)

data.head()
# Out:
#          Peptide  Peptide Length  Peptide Signal  Streptavidin Signal  \
# 0  AGQFQVWIPGAQK              13         0.00253             0.000011
# 1  AGQFQVWIPGAQK              13         0.00279            -0.000060
# 2  AGQFQVWIPGAQK              13         0.00336            -0.000017
# 3  AGQFQVWIPGAQK              13         0.00255            -0.000044
# 4  AGQFQVWIPGAQK              13         0.00187             0.000028
#
#    aMyc Signal  aMyc Association Signal  aMyc Dissociation Signal  Bad
# 0     0.000092                 0.000125                  0.000068    0
# 1     0.000054                 0.000130                  0.000026    0
# 2     0.000147                 0.000193                  0.000205    0
# 3     0.000129                 0.000052                  0.000090    0
# 4     0.000053                 0.000144                  0.000139    0

# %% [markdown]
# # Calculate mean and standard deviation by peptide

# %%
grouped = data.groupby(['Peptide',
                        'Peptide Length'])                       

f = {'Peptide Signal'           : [np.mean, np.std, stats.sem, len],
     'Streptavidin Signal'      : [np.mean, np.std, stats.sem],
     'aMyc Signal'              : [np.mean, np.std, stats.sem],
     'aMyc Association Signal'  : [np.mean, np.std, stats.sem],
     'aMyc Dissociation Signal' : [np.mean, np.std, stats.sem]}

# %%
result = grouped.agg(f)

# result.columns = result.columns.droplevel()
result.reset_index(inplace = True)

result.columns = ['Peptide',
                  'Peptide Length',    
                  
                  'Streptavidin Signal Mean',
                  'Streptavidin Signal SD',
                  'Streptavidin Signal SE',

                  'aMyc Dissociation Signal Mean',
                  'aMyc Dissociation Signal SD',
                  'aMyc Dissociation Signal SE',

                  'aMyc Association Signal Mean',
                  'aMyc Association Signal SD',
                  'aMyc Association Signal SE', 
                    
                  'aMyc Signal Mean',
                  'aMyc Signal SD',
                  'aMyc Signal SE',
                   
                  'Peptide Signal Mean',
                  'Peptide Signal SD',
                  'Peptide Signal SE',
                  
                  'Number of Spots']


result['Streptavidin Signal Mean NN'] = abs( result['Streptavidin Signal Mean']
                                          * (result['Streptavidin Signal Mean'] > 0) )
result['Peptide Signal Mean NN'] = abs( result['Peptide Signal Mean']
                                     * (result['Peptide Signal Mean'] > 0) )
result['aMyc Signal Mean NN'] = abs( result['aMyc Signal Mean']
                                  * (result['aMyc Signal Mean'] > 0) )
result['aMyc Association Signal Mean NN'] = abs( result['aMyc Association Signal Mean']
                                              * (result['aMyc Association Signal Mean'] > 0) )
result['aMyc Dissociation Signal Mean NN'] = abs( result['aMyc Dissociation Signal Mean']
                                               * (result['aMyc Dissociation Signal Mean'] > 0) )

result.head()
# Out:
#          Peptide  Peptide Length  Streptavidin Signal Mean  \
# 0  AGQFQVWIPGAQK              13                 -0.000002
# 1        AISPPPK               7                 -0.000018
# 2   AKFPIPLGKQSG              12                 -0.000031
# 3      AQWHPQAGK               9                  0.000783
# 4       ATHPQFAT               8                  0.000987
#
#    Streptavidin Signal SD  Streptavidin Signal SE  \
# 0                0.000043                0.000010
# 1                0.000051                0.000005
# 2                0.000030                0.000015
# 3                0.000087                0.000043
# 4                0.000136                0.000068
#
#    aMyc Dissociation Signal Mean  aMyc Dissociation Signal SD  \
# 0                       0.000165                     0.000081
# 1                       0.000135                     0.000118
# 2                       0.000207                     0.000037
# 3                       0.000101                     0.000077
# 4                      -0.000053                     0.000066
#
#    aMyc Dissociation Signal SE  aMyc Association Signal Mean  \
# 0                     0.000018                      0.000205
# 1                     0.000012                      0.000110
# 2                     0.000018                      0.000207
# 3                     0.000038                      0.000060
# 4                     0.000033                     -0.000132
#
#    aMyc Association Signal SD                ...                 \
# 0                    0.000091                ...
# 1                    0.000132                ...
# 2                    0.000091                ...
# 3                    0.000077                ...
# 4                    0.000143                ...
#
#    aMyc Signal SE  Peptide Signal Mean  Peptide Signal SD  Peptide Signal SE  \
# 0        0.000011             0.002625           0.000342           0.000077
# 1        0.000004             0.002833           0.000502           0.000051
# 2        0.000020             0.002910           0.000384           0.000192
# 3        0.000007             0.002933           0.000310           0.000155
# 4        0.000017             0.001607           0.000362           0.000181
#
#    Number of Spots  Streptavidin Signal Mean NN  Peptide Signal Mean NN  \
# 0               20                     0.000000                0.002625
# 1               98                     0.000000                0.002833
# 2                4                     0.000000                0.002910
# 3                4                     0.000783                0.002933
# 4                4                     0.000987                0.001607
#
#    aMyc Signal Mean NN  aMyc Association Signal Mean NN  \
# 0             0.000129                         0.000205
# 1             0.000097                         0.000110
# 2             0.000105                         0.000207
# 3             0.000047                         0.000060
# 4             0.000000                         0.000000
#
#    aMyc Dissociation Signal Mean NN
# 0                          0.000165
# 1                          0.000135
# 2                          0.000207
# 3                          0.000101
# 4                          0.000000
#
# [5 rows x 23 columns]

# %% [markdown]
# # Add weight, and sort

# %%
result['Peptide Weight'] = result['Peptide'].map(lambda x: weight(x, weights))
result.sort(['Peptide Length', 'Peptide'], inplace = True)
result = result.reset_index(drop = True)

result.head()
# Out:
#    Peptide  Peptide Length  Streptavidin Signal Mean  Streptavidin Signal SD  \
# 0  AISPPPK               7                 -0.000018                0.000051
# 1  THPQFAT               7                  0.000742                0.000101
# 2  WHPQFAT               7                  0.000610                0.000051
# 3  WTHPFAT               7                 -0.000002                0.000057
# 4  WTHPQAT               7                  0.000214                0.000045
#
#    Streptavidin Signal SE  aMyc Dissociation Signal Mean  \
# 0                0.000005                       0.000135
# 1                0.000058                       0.000008
# 2                0.000025                      -0.000016
# 3                0.000029                      -0.000047
# 4                0.000026                       0.000001
#
#    aMyc Dissociation Signal SD  aMyc Dissociation Signal SE  \
# 0                     0.000118                     0.000012
# 1                     0.000055                     0.000032
# 2                     0.000094                     0.000047
# 3                     0.000063                     0.000032
# 4                     0.000168                     0.000097
#
#    aMyc Association Signal Mean  aMyc Association Signal SD       ...        \
# 0                      0.000110                    0.000132       ...
# 1                      0.000024                    0.000063       ...
# 2                     -0.000004                    0.000068       ...
# 3                     -0.000158                    0.000073       ...
# 4                     -0.000053                    0.000216       ...
#
#    Peptide Signal Mean  Peptide Signal SD  Peptide Signal SE  Number of Spots  \
# 0             0.002833           0.000502           0.000051               98
# 1             0.001647           0.000257           0.000148                3
# 2             0.000924           0.000134           0.000067                4
# 3             0.001179           0.000203           0.000101                4
# 4             0.001800           0.000416           0.000240                3
#
#    Streptavidin Signal Mean NN  Peptide Signal Mean NN  aMyc Signal Mean NN  \
# 0                     0.000000                0.002833             0.000097
# 1                     0.000742                0.001647             0.000000
# 2                     0.000610                0.000924             0.000000
# 3                     0.000000                0.001179             0.000013
# 4                     0.000214                0.001800             0.000000
#
#    aMyc Association Signal Mean NN  aMyc Dissociation Signal Mean NN  \
# 0                         0.000110                          0.000135
# 1                         0.000024                          0.000008
# 2                         0.000000                          0.000000
# 3                         0.000000                          0.000000
# 4                         0.000000                          0.000001
#
#    Peptide Weight
# 0             708
# 1             801
# 2             886
# 3             858
# 4             840
#
# [5 rows x 24 columns]

# %%
# rearrange order of columns
result = result.reindex_axis(['Peptide',
                              'Number of Spots',
                              'Peptide Length',
                              'Peptide Weight',
                              
                              'Peptide Signal Mean',
                              'Peptide Signal Mean NN',
                              'Peptide Signal SD',
                              'Peptide Signal SE',
                              
                              'Streptavidin Signal Mean',
                              'Streptavidin Signal Mean NN',
                              'Streptavidin Signal SD',
                              'Streptavidin Signal SE',
                              
                              'aMyc Signal Mean',
                              'aMyc Signal Mean NN',
                              'aMyc Signal SD',
                              'aMyc Signal SE',              
                              
                              'aMyc Dissociation Signal Mean',
                              'aMyc Dissociation Signal Mean NN',
                              'aMyc Dissociation Signal SD',
                              'aMyc Dissociation Signal SE',

                              'aMyc Association Signal Mean',
                              'aMyc Association Signal Mean NN',
                              'aMyc Association Signal SD',
                              'aMyc Association Signal SE'], axis=1)
result.head()
# Out:
#    Peptide  Number of Spots  Peptide Length  Peptide Weight  \
# 0  AISPPPK               98               7             708
# 1  THPQFAT                3               7             801
# 2  WHPQFAT                4               7             886
# 3  WTHPFAT                4               7             858
# 4  WTHPQAT                3               7             840
#
#    Peptide Signal Mean  Peptide Signal Mean NN  Peptide Signal SD  \
# 0             0.002833                0.002833           0.000502
# 1             0.001647                0.001647           0.000257
# 2             0.000924                0.000924           0.000134
# 3             0.001179                0.001179           0.000203
# 4             0.001800                0.001800           0.000416
#
#    Peptide Signal SE  Streptavidin Signal Mean  Streptavidin Signal Mean NN  \
# 0           0.000051                 -0.000018                     0.000000
# 1           0.000148                  0.000742                     0.000742
# 2           0.000067                  0.000610                     0.000610
# 3           0.000101                 -0.000002                     0.000000
# 4           0.000240                  0.000214                     0.000214
#
#               ...              aMyc Signal SD  aMyc Signal SE  \
# 0             ...                    0.000042        0.000004
# 1             ...                    0.000007        0.000004
# 2             ...                    0.000024        0.000012
# 3             ...                    0.000032        0.000016
# 4             ...                    0.000012        0.000007
#
#    aMyc Dissociation Signal Mean  aMyc Dissociation Signal Mean NN  \
# 0                       0.000135                          0.000135
# 1                       0.000008                          0.000008
# 2                      -0.000016                          0.000000
# 3                      -0.000047                          0.000000
# 4                       0.000001                          0.000001
#
#    aMyc Dissociation Signal SD  aMyc Dissociation Signal SE  \
# 0                     0.000118                     0.000012
# 1                     0.000055                     0.000032
# 2                     0.000094                     0.000047
# 3                     0.000063                     0.000032
# 4                     0.000168                     0.000097
#
#    aMyc Association Signal Mean  aMyc Association Signal Mean NN  \
# 0                      0.000110                         0.000110
# 1                      0.000024                         0.000024
# 2                     -0.000004                         0.000000
# 3                     -0.000158                         0.000000
# 4                     -0.000053                         0.000000
#
#    aMyc Association Signal SD  aMyc Association Signal SE
# 0                    0.000132                    0.000013
# 1                    0.000063                    0.000037
# 2                    0.000068                    0.000034
# 3                    0.000073                    0.000036
# 4                    0.000216                    0.000125
#
# [5 rows x 24 columns]

# %%
result.to_csv('07 EP dIm Signals.csv', index = False)
