# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

from scipy import stats

# import sys
# sys.path.append('/home/galina/PythonProjects/common_functions')
# import peptides as pep
# %matplotlib inline

# sns.set_context('talk')
sns.set(font_scale = 1.5)

# %% [markdown]
# # Peptide data cleaning

# %%
df = pd.read_csv('18 EP dIm and dR Signals.csv', header = 0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4125 entries, 0 to 4124
# Data columns (total 23 columns):
# Grid Index                              4125 non-null int64
# Peptide                                 4125 non-null object
# Peptide Length                          4125 non-null int64
# Peptide Weight                          4125 non-null float64
# dIm EP Peptide Readout                  4125 non-null float64
# dIm EP Peptide Median                   4125 non-null float64
# dIm EP Peptide MAD                      4125 non-null float64
# dIm EP Streptavidin Readout             4125 non-null float64
# dIm EP Streptavidin Median              4125 non-null float64
# dIm EP Streptavidin MAD                 4125 non-null float64
# dIm EP Bad                              4125 non-null bool
# dR EP Peptide Readout                   4125 non-null float64
# dR EP Peptide Median                    4125 non-null float64
# dR EP Peptide MAD                       4125 non-null float64
# dR EP Streptavidin Readout              4125 non-null float64
# dR EP Streptavidin Median               4125 non-null float64
# dR EP Streptavidin MAD                  4125 non-null float64
# dR EP Bad                               4125 non-null bool
# dR RT Streptavidin Baseline Noise       3195 non-null float64
# dR RT Streptavidin Association Mean     3195 non-null float64
# dR RT Streptavidin Dissociation Mean    3195 non-null float64
# dR RT Streptavidin Association SNR      3195 non-null float64
# dR RT Bad                               4125 non-null bool
# dtypes: bool(3), float64(17), int64(2), object(1)
# memory usage: 688.8+ KB

# %% [markdown]
# See **19 Compare dIm EP and dR EP** notebook for comparison of dIm EP and dR EP streptavidin signals. Last plot shows that $ \text{dIm} \approx 2.14 \times \text{dR} $.

# %%
dR_to_dIm = 2.14
df_reacted = df[df['dR RT Streptavidin Association SNR'] > 2]
sns.distplot(df_reacted['dR RT Streptavidin Association Mean'] * dR_to_dIm * 1000,
             kde = False, norm_hist = False, # bins = 40,
             hist_kws={'histtype' : 'stepfilled', 'alpha': 0.6, 'color' : sns.color_palette('Blues_r')[0]})
sns.distplot(df_reacted['dR RT Streptavidin Dissociation Mean'] * dR_to_dIm * 1000,
             kde = False, norm_hist = False, # bins = 40,
             hist_kws={'histtype' : 'stepfilled', 'alpha': 0.7, 'color' : sns.color_palette('Blues_r')[1]})
sns.distplot(df_reacted['dR EP Streptavidin Median'] * dR_to_dIm * 1000,
             kde = False, norm_hist = False, # bins = 40,
             hist_kws={'histtype' : 'stepfilled', 'alpha': 0.7, 'color' : sns.color_palette('Blues_r')[2]})
# sns.distplot(df_reacted['dR RT Streptavidin Baseline Noise'] * dR_to_dIm * 1000,
#              kde = False, norm_hist = False, bins = 10,
#              hist_kws={'histtype' : 'stepfilled', 'alpha': 0.8})
# sns.distplot(df_reacted['dR EP Streptavidin Median'] * dR_to_dIm * 1000,
#              kde = False, norm_hist = False, # bins = 40,
#              hist_kws={'histtype' : 'stepfilled', 'alpha': 0.8})
# sns.distplot(df_reacted['dIm EP Streptavidin Median'] * 1000,
#              kde = False, norm_hist = False, # bins = 40,
#              hist_kws={'histtype' : 'stepfilled', 'alpha': 0.8})
plt.xlabel('OI-RD signal [mrad]')
plt.ylabel('Count')
# sns.distplot(df_reacted['dR RT Streptavidin Dissociation Mean'] * dR_to_dIm * 1000)
# sns.distplot(df_reacted['dIm EP Streptavidin Median'] * 1000)

# %%
df_reacted = df[df['dR RT Streptavidin Association SNR'] > 2]
sns.distplot(df_reacted['dR RT Streptavidin Association Mean'] * dR_to_dIm * 1000,
             kde = False, norm_hist = False, # bins = 40,
             hist_kws={'histtype' : 'step', 'lw' : 5, 'alpha' : 0.8, 'color' : sns.color_palette('Blues_r')[0]})
sns.distplot(df_reacted['dR RT Streptavidin Dissociation Mean'] * dR_to_dIm * 1000,
             kde = False, norm_hist = False, # bins = 40,
             hist_kws={'histtype' : 'step', 'lw' : 5, 'alpha' : 0.8, 'color' : sns.color_palette('Blues_r')[1]})
sns.distplot(df_reacted['dR EP Streptavidin Median'] * dR_to_dIm * 1000,
             kde = False, norm_hist = False, # bins = 40,
             hist_kws={'histtype' : 'step', 'lw' : 5, 'alpha': 0.8, 'color' : sns.color_palette('Blues_r')[2]})
# sns.distplot(df_reacted['dR RT Streptavidin Baseline Noise'] * dR_to_dIm * 1000,
#              kde = False, norm_hist = False, bins = 10,
#              hist_kws={'histtype' : 'stepfilled', 'alpha': 0.8})
# sns.distplot(df_reacted['dR EP Streptavidin Median'] * dR_to_dIm * 1000,
#              kde = False, norm_hist = False, # bins = 40,
#              hist_kws={'histtype' : 'stepfilled', 'alpha': 0.8})
# sns.distplot(df_reacted['dIm EP Streptavidin Median'] * 1000,
#              kde = False, norm_hist = False, # bins = 40,
#              hist_kws={'histtype' : 'stepfilled', 'alpha': 0.8})
plt.xlabel('OI-RD signal [mrad]')
plt.ylabel('Count')
# sns.distplot(df_reacted['dR RT Streptavidin Dissociation Mean'] * dR_to_dIm * 1000)
# sns.distplot(df_reacted['dIm EP Streptavidin Median'] * 1000)

# %%
ax = sns.distplot(x, kde = False, norm_hist = True)

# %%
ax = sns.distplot(x, kde = False, norm_hist = False)

# %%
df_reacted[df_reacted['dR RT Streptavidin Association Mean'] > 0.0018]
# Out:
#       Grid Index        Peptide  Peptide Length  Peptide Weight  \
# 882           51       WTHPQFAT               8         987.083
# 908         2235       WTHPQFAT               8         987.083
# 1208        4517       YTHPQFAT               8         964.046
# 1513        2229      LQWHPQAGA               9        1007.118
# 2912        3989   PKFPIPLGKQSG              12        1268.524
# 3860        3990  NGQFQVWIVGAQK              13        1474.685
#
#       dIm EP Peptide Readout  dIm EP Peptide Median  dIm EP Peptide MAD  \
# 882                 0.001890               0.001490            0.000158
# 908                 0.000389               0.000748            0.000249
# 1208                0.001921               0.001758            0.000221
# 1513                0.002103               0.002462            0.000351
# 2912                0.001960               0.001815            0.000321
# 3860                0.000632               0.000733            0.000348
#
#       dIm EP Streptavidin Readout  dIm EP Streptavidin Median  \
# 882                      0.002007                    0.002073
# 908                      0.002076                    0.001758
# 1208                     0.001735                    0.001929
# 1513                     0.001744                    0.001441
# 2912                     0.000136                    0.000033
# 3860                     0.000100                    0.000100
#
#       dIm EP Streptavidin MAD    ...     dR EP Peptide MAD  \
# 882                  0.000167    ...              0.000144
# 908                  0.000228    ...              0.000192
# 1208                 0.000175    ...              0.000326
# 1513                 0.000162    ...              0.000259
# 2912                 0.000119    ...              0.000372
# 3860                 0.000141    ...              0.000189
#
#       dR EP Streptavidin Readout  dR EP Streptavidin Median  \
# 882                     0.001418                   0.001084
# 908                     0.000783                   0.000597
# 1208                    0.000574                   0.000912
# 1513                    0.000719                   0.000554
# 2912                    0.000316                   0.000245
# 3860                    0.000218                   0.000233
#
#       dR EP Streptavidin MAD  dR EP Bad  dR RT Streptavidin Baseline Noise  \
# 882                 0.000279      False                           0.000168
# 908                 0.000234      False                           0.000195
# 1208                0.000259      False                           0.000222
# 1513                0.000233      False                           0.000275
# 2912                0.000235       True                           0.000219
# 3860                0.000211      False                           0.000191
#
#       dR RT Streptavidin Association Mean  \
# 882                              0.001817
# 908                              0.001801
# 1208                             0.001807
# 1513                             0.001843
# 2912                             0.002181
# 3860                             0.001880
#
#      dR RT Streptavidin Dissociation Mean  dR RT Streptavidin Association SNR  \
# 882                              0.001633                           10.794892
# 908                              0.001148                            9.217752
# 1208                             0.001183                            8.141744
# 1513                             0.001624                            6.709864
# 2912                             0.001895                            9.952406
# 3860                             0.002304                            9.817248
#
#       dR RT Bad
# 882       False
# 908       False
# 1208      False
# 1513      False
# 2912      False
# 3860      False
#
# [6 rows x 23 columns]

# %%
sns.distplot(df['dR RT Streptavidin Baseline Noise'].dropna().reset_index(drop = True) * 1000, bins = 20)

# %%
# df['dR RT Streptavidin Baseline Noise'].dropna().reset_index(drop = True)
# Out:
# 0       0.000266
# 1       0.000185
# 2       0.000112
# 3       0.000159
# 4       0.000160
# 5       0.000185
# 6       0.000220
# 7       0.000217
# 8       0.000240
# 9       0.000187
# 10      0.000211
# 11      0.000196
# 12      0.000184
# 13      0.000217
# 14      0.000163
# 15      0.000279
# 16      0.000217
# 17      0.000216
# 18      0.000168
# 19      0.000293
# 20      0.000250
# 21      0.000327
# 22      0.000241
# 23      0.000219
# 24      0.000185
# 25      0.000280
# 26      0.000211
# 27      0.000273
# 28      0.000159
# 29      0.000195
#           ...
# 3165    0.000158
# 3166    0.000187
# 3167    0.000269
# 3168    0.000167
# 3169    0.000304
# 3170    0.000216
# 3171    0.000213
# 3172    0.000209
# 3173    0.000191
# 3174    0.000264
# 3175    0.000195
# 3176    0.000305
# 3177    0.000138
# 3178    0.000159
# 3179    0.000245
# 3180    0.000213
# 3181    0.000241
# 3182    0.000183
# 3183    0.000187
# 3184    0.000186
# 3185    0.000212
# 3186    0.000265
# 3187    0.000137
# 3188    0.000189
# 3189    0.000211
# 3190    0.000211
# 3191    0.000189
# 3192    0.000160
# 3193    0.000191
# 3194    0.000253
# Name: dR RT Streptavidin Baseline Noise, dtype: float64

# %%
tmp = data[data['Peptide Length'] == 13][['Peptide', 'Peptide Length']].groupby('Peptide').agg(len)
tmp = tmp.reset_index().sort(['Peptide Length', 'Peptide']).reset_index()
tmp
#tmp[~tmp['Peptide'].str.contains('QSG')]
# Out:
#      index        Peptide  Peptide Length
# 0        9  LGQFQVWIPGAQK               4
# 1       10  MGQFQVWIPGAQK               4
# 2       11  NAQFQVWIPGAQK               4
# 3       12  NCQFQVWIPGAQK               4
# 4       13  NDQFQVWIPGAQK               4
# 5       14  NEQFQVWIPGAQK               4
# 6       15  NFQFQVWIPGAQK               4
# 7       16  NGAFQVWIPGAQK               4
# 8       17  NGCFQVWIPGAQK               4
# 9       18  NGDFQVWIPGAQK               4
# 10      19  NGEFQVWIPGAQK               4
# 11      20  NGFFQVWIPGAQK               4
# 12      21  NGGFQVWIPGAQK               4
# 13      22  NGHFQVWIPGAQK               4
# 14      23  NGIFQVWIPGAQK               4
# 15      24  NGKFQVWIPGAQK               4
# 16      25  NGLFQVWIPGAQK               4
# 17      26  NGMFQVWIPGAQK               4
# 18      27  NGNFQVWIPGAQK               4
# 19      28  NGPFQVWIPGAQK               4
# 20      29  NGQAQVWIPGAQK               4
# 21      30  NGQCQVWIPGAQK               4
# 22      31  NGQDQVWIPGAQK               4
# 23      32  NGQEQVWIPGAQK               4
# 24      33  NGQFAVWIPGAQK               4
# 25      34  NGQFCVWIPGAQK               4
# 26      35  NGQFDVWIPGAQK               4
# 27      36  NGQFEVWIPGAQK               4
# 28      37  NGQFFVWIPGAQK               4
# 29      38  NGQFGVWIPGAQK               4
# ..     ...            ...             ...
# 218    228  NKQFQVWIPGAQK               4
# 219    229  NLQFQVWIPGAQK               4
# 220    230  NMQFQVWIPGAQK               4
# 221    231  NNQFQVWIPGAQK               4
# 222    232  NPQFQVWIPGAQK               4
# 223    233  NQQFQVWIPGAQK               4
# 224    234  NRQFQVWIPGAQK               4
# 225    235  NSQFQVWIPGAQK               4
# 226    236  NTQFQVWIPGAQK               4
# 227    237  NVQFQVWIPGAQK               4
# 228    238  NWQFQVWIPGAQK               4
# 229    239  NYQFQVWIPGAQK               4
# 230    240  PGQFQVWIPGAQK               4
# 231    241  QGQFQVWIPGAQK               4
# 232    242  RGQFQVWIPGAQK               4
# 233    243  SGQFQVWIPGAQK               4
# 234    244  TGQFQVWIPGAQK               4
# 235    245  VGQFQVWIPGAQK               4
# 236    246  WGQFQVWIPGAQK               4
# 237    247  YGQFQVWIPGAQK               4
# 238      0  AGQFQVWIPGAQK              20
# 239      1  CGQFQVWIPGAQK              20
# 240      2  DGQFQVWIPGAQK              20
# 241      3  EGQFQVWIPGAQK              20
# 242      4  FGQFQVWIPGAQK              20
# 243      5  GGQFQVWIPGAQK              20
# 244      6  HGQFQVWIPGAQK              20
# 245      7  IGQFQVWIPGAQK              20
# 246      8  KGQFQVWIPGAQK              20
# 247    126  NGQFQVWIPGAQK              52
#
# [248 rows x 3 columns]

# %% [markdown]
# # Calculate mean and standard deviation by peptide

# %%
grouped_dIm = data[ data['dIm EP Bad'] == 0 ].groupby(['Peptide'])                      
grouped_dR  = data[ data['dR EP Bad']  == 0 ].groupby(['Peptide']) 

f_dIm = {'Peptide Length'             : {'Peptide Length'          : 'first'},
         'Peptide Weight'             : {'Peptide Weight'          : 'first'},
         'dIm EP Peptide Median'      : {'dIm EP Peptide Mean'     : np.mean,
                                         'dIm EP Peptide SE'       : stats.sem,
                                         'Number of dIm EP Spots'  : len},
         'dIm EP Streptavidin Median' : {'dIm EP Streptavidin Mean' : np.mean,
                                         'dIm EP Streptavidin SE'  : stats.sem}}

f_dR  = {'dR EP Peptide Median'       : {'dR EP Peptide Mean'      : np.mean,
                                         'dR EP Peptide SE'        : stats.sem,
                                         'Number of dR EP Spots'   : len},
         'dR EP Streptavidin Median'  : {'dR EP Streptavidin Mean'  : np.mean,
                                         'dR EP Streptavidin SE'   : stats.sem}}     

result_dIm = grouped_dIm.agg(f_dIm)
result_dR  = grouped_dR.agg(f_dR)

result_dIm.columns = result_dIm.columns.droplevel()
result_dR.columns  = result_dR.columns.droplevel()

result_dIm.reset_index(inplace = True)
result_dR.reset_index(inplace = True)

result_dIm['dIm EP Streptavidin Mean NN'] = result_dIm['dIm EP Streptavidin Mean'].clip(lower = 0)
result_dIm['dIm EP Peptide Mean NN']      = result_dIm['dIm EP Peptide Mean'].clip(lower = 0)

result_dR['dR EP Streptavidin Mean NN'] = result_dR['dR EP Streptavidin Mean'].clip(lower = 0)
result_dR['dR EP Peptide Mean NN']      = result_dR['dR EP Peptide Mean'].clip(lower = 0)

result = pd.merge(result_dIm, result_dR, how = 'outer', on = 'Peptide')
result.sort(['Peptide Length', 'Peptide'], inplace = True)
result = result.reset_index(drop = True)

result = result.reindex_axis(['Peptide',
                              'Peptide Length',
                              'Peptide Weight',
                              
                              'Number of dIm EP Spots',
                              'dIm EP Peptide Mean',
                              'dIm EP Peptide Mean NN',
                              'dIm EP Peptide SE',
                              'dIm EP Streptavidin Mean',
                              'dIm EP Streptavidin Mean NN',
                              'dIm EP Streptavidin SE',
                             
                              'Number of dR EP Spots',
                              'dR EP Peptide Mean',
                              'dR EP Peptide Mean NN',
                              'dR EP Peptide SE',
                              'dR EP Streptavidin Mean',
                              'dR EP Streptavidin Mean NN',
                              'dR EP Streptavidin SE'], axis=1)

result.head()
# Out:
#     Peptide  Peptide Length  Peptide Weight  Number of dIm EP Spots  \
# 0  ATHPQFAT               8         871.949                       4
# 1  CTHPQFAT               8         904.009                       4
# 2  DTHPQFAT               8         915.959                       4
# 3  DYKDDDDK               8        1012.984                      99
# 4  ETHPQFAT               8         929.986                       4
#
#    dIm EP Peptide Mean  dIm EP Peptide Mean NN  dIm EP Peptide SE  \
# 0             0.001384                0.001384           0.000084
# 1             0.001125                0.001125           0.000035
# 2             0.001391                0.001391           0.000062
# 3             0.005810                0.005810           0.000087
# 4             0.001740                0.001740           0.000131
#
#    dIm EP Streptavidin Mean  dIm EP Streptavidin Mean NN  \
# 0                  0.001445                     0.001445
# 1                  0.001317                     0.001317
# 2                  0.001412                     0.001412
# 3                 -0.000086                     0.000000
# 4                  0.001277                     0.001277
#
#    dIm EP Streptavidin SE  Number of dR EP Spots  dR EP Peptide Mean  \
# 0                0.000100                      4            0.001181
# 1                0.000129                      4            0.001023
# 2                0.000073                      4            0.001054
# 3                0.000009                     99            0.002899
# 4                0.000064                      4            0.000894
#
#    dR EP Peptide Mean NN  dR EP Peptide SE  dR EP Streptavidin Mean  \
# 0               0.001181          0.000018                 0.000627
# 1               0.001023          0.000065                 0.000608
# 2               0.001054          0.000054                 0.000640
# 3               0.002899          0.000055                 0.000089
# 4               0.000894          0.000111                 0.000618
#
#    dR EP Streptavidin Mean NN  dR EP Streptavidin SE
# 0                    0.000627               0.000115
# 1                    0.000608               0.000100
# 2                    0.000640               0.000065
# 3                    0.000089               0.000014
# 4                    0.000618               0.000047

# %%
result.to_csv('18 EP dIm and dR Signals aggregated.csv', index = False)

# %%
# result[result['Peptide'] == 'NCQFQVWIPGAQK']

# %%
# data[data['Peptide'] == 'NCQFQVWIPGAQK']

# %%
# data[data['dR EP Peptide MAD'] > 0.005]

# %%
import seaborn as sns, numpy as np
sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = np.random.randn(100)
ax = sns.distplot(x)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-24-acb0aad4e536> in <module>()
#       2 sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
#       3 x = np.random.randn(100)
# ----> 4 ax = sns.distplot(x)
#
# /home/galina/.local/lib/python2.7/site-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     210         hist_color = hist_kws.pop("color", color)
#     211         ax.hist(a, bins, orientation=orientation,
# --> 212                 color=hist_color, **hist_kws)
#     213         if hist_color != color:
#     214             hist_kws["color"] = hist_color
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6190             # this will automatically overwrite bins,
#    6191             # so that each histogram uses the same bins
# -> 6192             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6193             m = m.astype(float)  # causes problems later if it's an int
#    6194             if mlast is None:
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     726
#     727         # Initialize empty histogram
# --> 728         n = np.zeros(bins, ntype)
#     729         # Pre-compute histogram scaling factor
#     730         norm = bins / (mx - mn)
#
# TypeError: 'numpy.float64' object cannot be interpreted as an index
