# %%
import numpy as np
import pandas as pd
import os

from scipy import stats

import sys
sys.path.append('/home/galina/PythonProjects/common_functions')
import peptides as pep

# %% [markdown]
# # Peptide data cleaning

# %%
data = pd.read_csv('EP signals from dIm EP and dR RT.csv', header = 0)

drop_col = ['Column',
            'Row',
            'Peptide SD',
#            'Peptide Median',
            'Peptide Max',
            'Peptide Min',
            'Streptavidin SD',
#            'Streptavidin Median',
            'Streptavidin Max',
            'Streptavidin Min',
            'Baseline Mean',
            'Dissociation SNR']
data.rename(columns = {'Index' : 'Grid Index',
                       'Label' : 'Peptide'}, inplace = True)

# Add 'Bad' columns
bad_indices = [int(x) for x in np.genfromtxt("bad spots.txt", delimiter="\n")]
binary_bad = [False] * len(data)
for i in bad_indices:
    binary_bad[i] = True

data['Bad EP']         = binary_bad
data['Bad RT']         = (data['Association SNR'].isnull())
data['Peptide Weight'] = data['Peptide'].map(pep.weight)
data['Peptide Length'] = data['Peptide'].map(lambda x : len(str(x)))

data.drop(drop_col, axis = 1, inplace = True)
data.head()
# Out:
#    Grid Index        Peptide  Peptide Readout  Peptide Mean  Peptide Median  \
# 0           0       WTHPQFAT         0.000387      0.000899        0.000924
# 1           1       WTHPQFAT         0.000360      0.000606        0.000659
# 2           2       WTHLQFAT         0.000223      0.000304        0.000311
# 3           3  NGQFQVWIPLAQK         0.002042      0.001883        0.001970
# 4           4      LQLHPQAGK         0.003436      0.003312        0.003363
#
#    Peptide MAD  Streptavidin Readout  Streptavidin Mean  Streptavidin Median  \
# 0     0.000241              0.001759           0.001738             0.001743
# 1     0.000338              0.001839           0.001741             0.001741
# 2     0.000148             -0.000018           0.000005             0.000024
# 3     0.000265             -0.000196          -0.000061            -0.000035
# 4     0.000187              0.000476           0.000580             0.000593
#
#    Streptavidin MAD  Baseline Noise  Association Mean  Dissociation Mean  \
# 0          0.000143        0.000211          0.001505           0.001104
# 1          0.000107        0.000263          0.000903           0.000765
# 2          0.000095        0.000237         -0.000066           0.000072
# 3          0.000107        0.000237         -0.000120          -0.000145
# 4          0.000101        0.000237          0.000639           0.000319
#
#    Association SNR Bad EP Bad RT  Peptide Weight  Peptide Length
# 0         7.134546  False  False         987.083               8
# 1         3.429684  False  False         987.083               8
# 2        -0.280433  False  False        1003.126               8
# 3        -0.504192  False  False        1528.777              13
# 4         2.693665  False  False         991.160               9

# %%
# remove NaNs, Xs and bad spots
data.dropna(subset = ['Peptide'], inplace = True)
data = data[ data['Peptide'] != 'X' ]
data = data[ data['Bad EP'] == 0 ]

lengths = [8, 9, 12, 13]
data = data[data['Peptide Length'].isin(lengths)]

data.sort(['Peptide Length', 'Peptide'], inplace = True)
data = data.reset_index(drop = True)

data.head()
# Out:
#    Grid Index   Peptide  Peptide Readout  Peptide Mean  Peptide Median  \
# 0         527  ATHPQFAT         0.001120      0.001038        0.001142
# 1         734  ATHPQFAT         0.001381      0.001484        0.001501
# 2        1033  ATHPQFAT         0.001809      0.001440        0.001495
# 3        1668  ATHPQFAT         0.001379      0.001355        0.001397
# 4         793  CTHPQFAT         0.000929      0.001066        0.001053
#
#    Peptide MAD  Streptavidin Readout  Streptavidin Mean  Streptavidin Median  \
# 0     0.000190              0.001197           0.001186             0.001182
# 1     0.000182              0.001503           0.001451             0.001487
# 2     0.000217              0.001348           0.001640             0.001667
# 3     0.000195              0.001651           0.001417             0.001444
# 4     0.000129              0.001015           0.001186             0.001179
#
#    Streptavidin MAD  Baseline Noise  Association Mean  Dissociation Mean  \
# 0          0.000122        0.000266          0.000825           0.000553
# 1          0.000144        0.000185          0.001086           0.000779
# 2          0.000143        0.000112          0.001556           0.001509
# 3          0.000115        0.000159          0.000830           0.000804
# 4          0.000193        0.000160          0.001053           0.000747
#
#    Association SNR Bad EP Bad RT  Peptide Weight  Peptide Length
# 0         3.099982  False  False         871.949               8
# 1         5.865785  False  False         871.949               8
# 2        13.933146  False  False         871.949               8
# 3         5.234234  False  False         871.949               8
# 4         6.570487  False  False         904.009               8

# %% [markdown]
# # Calculate mean and standard deviation by peptide

# %%
grouped = data.groupby(['Peptide',
                        'Peptide Length',
                        'Peptide Weight'])                       

f = {'Peptide Median'           : [np.mean, stats.sem, len],
     'Streptavidin Median'      : [np.mean, stats.sem]}

# %%
result = grouped.agg(f)

result.reset_index(inplace = True)

result.columns = ['Peptide',
                  'Peptide Length',
                  'Peptide Weight',

                  'Peptide Mean',
                  'Peptide SE',
                  
                  'Number of Spots',
                 
                  'Streptavidin Mean',
                  'Streptavidin SE',]


result['Streptavidin Mean NN'] = result['Streptavidin Mean'].clip(lower = 0)
result['Peptide Mean NN']      = result['Peptide Mean'].clip(lower = 0)

result.head()
# Out:
#          Peptide  Peptide Length  Peptide Weight  Peptide Mean  Peptide SE  \
# 0  AGQFQVWIPGAQK              13        1429.644      0.002517    0.000109
# 1   AKFPIPLGKQSG              12        1242.486      0.003058    0.000181
# 2      AQWHPQAGK               9        1022.132      0.003245    0.000227
# 3       ATHPQFAT               8         871.949      0.001384    0.000084
# 4  CGQFQVWIPGAQK              13        1461.704      0.002316    0.000110
#
#    Number of Spots  Streptavidin Mean  Streptavidin SE  Streptavidin Mean NN  \
# 0               20          -0.000015         0.000013              0.000000
# 1                4          -0.000059         0.000016              0.000000
# 2                4           0.001123         0.000053              0.001123
# 3                4           0.001445         0.000100              0.001445
# 4               19          -0.000019         0.000022              0.000000
#
#    Peptide Mean NN
# 0         0.002517
# 1         0.003058
# 2         0.003245
# 3         0.001384
# 4         0.002316

# %% [markdown]
# # Add weight, and sort

# %%
result.sort(['Peptide Length', 'Peptide'], inplace = True)
result = result.reset_index(drop = True)

result.head()
# Out:
#     Peptide  Peptide Length  Peptide Weight  Peptide Mean  Peptide SE  \
# 0  ATHPQFAT               8         871.949      0.001384    0.000084
# 1  CTHPQFAT               8         904.009      0.001125    0.000035
# 2  DTHPQFAT               8         915.959      0.001391    0.000062
# 3  DYKDDDDK               8        1012.984      0.005810    0.000087
# 4  ETHPQFAT               8         929.986      0.001740    0.000131
#
#    Number of Spots  Streptavidin Mean  Streptavidin SE  Streptavidin Mean NN  \
# 0                4           0.001445         0.000100              0.001445
# 1                4           0.001317         0.000129              0.001317
# 2                4           0.001412         0.000073              0.001412
# 3               99          -0.000086         0.000009              0.000000
# 4                4           0.001277         0.000064              0.001277
#
#    Peptide Mean NN
# 0         0.001384
# 1         0.001125
# 2         0.001391
# 3         0.005810
# 4         0.001740

# %%
# rearrange order of columns
result = result.reindex_axis(['Peptide',
                              'Number of Spots',
                              'Peptide Length',
                              'Peptide Weight',
                              
                              'Peptide Mean',
                              'Peptide Mean NN',
                              'Peptide SE',
                              
                              'Streptavidin Mean',
                              'Streptavidin Mean NN',
                              'Streptavidin SE'], axis=1)
result.head()
# Out:
#     Peptide  Number of Spots  Peptide Length  Peptide Weight  Peptide Mean  \
# 0  ATHPQFAT                4               8         871.949      0.001384
# 1  CTHPQFAT                4               8         904.009      0.001125
# 2  DTHPQFAT                4               8         915.959      0.001391
# 3  DYKDDDDK               99               8        1012.984      0.005810
# 4  ETHPQFAT                4               8         929.986      0.001740
#
#    Peptide Mean NN  Peptide SE  Streptavidin Mean  Streptavidin Mean NN  \
# 0         0.001384    0.000084           0.001445              0.001445
# 1         0.001125    0.000035           0.001317              0.001317
# 2         0.001391    0.000062           0.001412              0.001412
# 3         0.005810    0.000087          -0.000086              0.000000
# 4         0.001740    0.000131           0.001277              0.001277
#
#    Streptavidin SE
# 0         0.000100
# 1         0.000129
# 2         0.000073
# 3         0.000009
# 4         0.000064

# %%
result.to_csv('12 EP dIm Signals.csv', index = False)

# %%
# result[result['Peptide'] == 'NCQFQVWIPGAQK']

# %%
# data[data['Peptide'] == 'NCQFQVWIPGAQK']
